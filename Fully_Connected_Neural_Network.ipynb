# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score as calculate_f1_score 
from sklearn.metrics import precision_score, recall_score, accuracy_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
torch.set_printoptions(edgeitems=2, linewidth=75)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %%
# Preprocess the data
file_path = r'/home/charlie51135/ml_final/dataset.csv'
dataframe = pd.read_csv(file_path)
# Check for null values
# print(dataframe.isnull().sum()*100/dataframe.shape[0])

# Convert 'Date' column to datetime and extract month and year
dataframe['Date'] = pd.to_datetime(dataframe['Date'])
dataframe['Month'] = dataframe['Date'].dt.month
dataframe['Year'] = dataframe['Date'].dt.year
dataframe = dataframe.drop(columns=['Date'])

# Map 'Year' to a number representing the order
dataframe['Year'] = dataframe['Year'] - dataframe['Year'].min()

# Target variable 'SPX'
y = dataframe.pop('SPX').values

# Set up the one-hot encoder for the 'Month' column and StandardScaler to remaining
continuous_columns = [col for col in dataframe.columns if col != 'Month']

preprocessor = ColumnTransformer(
    transformers=[
        ('month', OneHotEncoder(), ['Month']),
        ('scale', StandardScaler(), continuous_columns)
    ])

# Apply the pipeline to the data
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])
X_data = pipeline.fit_transform(dataframe)

# Convert to tensors
X_tensor = torch.tensor(X_data, dtype=torch.float32)
y_tensor = torch.tensor(y, dtype=torch.long)

# Split training and test data
torch.manual_seed(123)
n_samples = X_tensor.shape[0]
n_val = int(n_samples * 0.2)
shuffled_indices = torch.randperm(n_samples)
train_indices = shuffled_indices[:-n_val]
val_indices = shuffled_indices[-n_val:]

# Create tensors
X_train = X_tensor[train_indices].to(device, non_blocking=True)
y_train = y_tensor[train_indices].to(device, non_blocking=True)
X_val = X_tensor[val_indices].to(device, non_blocking=True)
y_val = y_tensor[val_indices].to(device, non_blocking=True)

# Create TensorDatasets
train_dataset = TensorDataset(X_train, y_train)
val_dataset = TensorDataset(X_val, y_val)

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32)

# %%
# NN model class- no dropout or batch normalization
class FCNN_Base(nn.Module):
    def __init__(self, n_chans1, hid_layers, activation_function):
        super(FCNN_Base, self).__init__()
        self.hid_layers = hid_layers

        # First hidden layer
        self.layer1 = nn.Linear(71, n_chans1)

        # Conditional layers
        if hid_layers > 1:
            self.layer2 = nn.Linear(n_chans1, n_chans1 * 2)
        if hid_layers > 2:
            self.layer3 = nn.Linear(n_chans1 * 2, n_chans1 // 2)

        # Output layer
        if hid_layers == 1:
            self.layer4 = nn.Linear(n_chans1, 2)
        elif hid_layers == 2:
            self.layer4 = nn.Linear(n_chans1 * 2, 2)
        else:  # hid_layers == 3
            self.layer4 = nn.Linear(n_chans1 // 2, 2)
        
        self.activation = activation_function

    # Define forward path
    def forward(self, x):
        out = self.activation(self.layer1(x))
        if self.hid_layers > 1:
            out = self.activation(self.layer2(out))
        if self.hid_layers > 2:
            out = self.activation(self.layer3(out))
        out = self.layer4(out)
        return out


# NN model class with dropout and batch normalization
class FCNN(nn.Module):
    def __init__(self, n_chans1, hid_layers, activation_function, dropout_prob):
        super(FCNN, self).__init__()
        self.hid_layers = hid_layers

        # First hidden layer
        self.layer1 = nn.Linear(71, n_chans1)
        self.bn1 = nn.BatchNorm1d(n_chans1)
        self.dropout1 = nn.Dropout(dropout_prob)

        # Conditional layers
        if hid_layers > 1:
            self.layer2 = nn.Linear(n_chans1, n_chans1 * 2)
            self.bn2 = nn.BatchNorm1d(n_chans1 * 2)
            self.dropout2 = nn.Dropout(dropout_prob)
        if hid_layers > 2:
            self.layer3 = nn.Linear(n_chans1 * 2, n_chans1 // 2)
            self.bn3 = nn.BatchNorm1d(n_chans1 // 2)
            self.dropout3 = nn.Dropout(dropout_prob)

        # Output layer
        if hid_layers == 1:
            self.layer4 = nn.Linear(n_chans1, 2)
        elif hid_layers == 2:
            self.layer4 = nn.Linear(n_chans1 * 2, 2)
        else:  # hid_layers == 3
            self.layer4 = nn.Linear(n_chans1 // 2, 2)

        self.activation = activation_function

    # Define forward path
    def forward(self, x):
        out = self.dropout1(self.activation(self.bn1(self.layer1(x))))
        if self.hid_layers > 1:
            out = self.dropout2(self.activation(self.bn2(self.layer2(out))))
        if self.hid_layers > 2:
            out = self.dropout3(self.activation(self.bn3(self.layer3(out))))
        out = self.layer4(out)
        return out

# Validation function to calculate all metrics
def validate(model, train_loader, val_loader):
    model.eval()
    results = {
        "train": {"accuracy": 0, "f1_score": 0, "precision": 0, "recall": 0},
        "val": {"accuracy": 0, "f1_score": 0, "precision": 0, "recall": 0}
    }
    loaders = {"train": train_loader, "val": val_loader}

    for phase in ['train', 'val']:
        all_preds = []
        all_targets = []

        for X, y in loaders[phase]:
            with torch.no_grad():
                outputs = model(X)
                _, predicted = torch.max(outputs, 1)
                all_preds.extend(predicted.cpu().numpy())
                all_targets.extend(y.cpu().numpy())

        accuracy = accuracy_score(all_targets, all_preds)
        f1 = calculate_f1_score(all_targets, all_preds, average='binary')
        precision = precision_score(all_targets, all_preds, average='binary', zero_division=0)
        recall = recall_score(all_targets, all_preds, average='binary', zero_division=0)
        
        results[phase]["accuracy"] = accuracy
        results[phase]["f1_score"] = f1
        results[phase]["precision"] = precision
        results[phase]["recall"] = recall

    return results

# Training loop function
def training_loop(n_epochs, early_stop, train_updates, optimizer, model, loss_fn, train_loader, val_loader):
    best_score = 0.0
    epochs_without_improvement = 0
    for epoch in range(1, n_epochs + 1):
        model.train()
        running_loss = 0.0

        for X_batch, y_batch in train_loader:
            train_y_pred = model(X_batch)
            train_loss = loss_fn(train_y_pred, y_batch)

            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()

            running_loss += train_loss.item()

        avg_train_loss = running_loss / len(train_loader)

        model.eval()
        results = validate(model, train_loader, val_loader)

        # Optional print results per x epochs
        if epoch % 5 == 0 and train_updates == True:
            print(f"Epoch: {epoch}, Training Loss: {avg_train_loss:.6f}, "
                f"Training Accuracy: {results['train']['accuracy']:.4f}, "
                f"Validation Accuracy: {results['val']['accuracy']:.4f}")
            
        # Early stopping check using accuracy
        if early_stop == True:
            val_score = results['val']['accuracy']
            if val_score > best_score:
                best_score = val_score
                epochs_without_improvement = 0
            else:
                epochs_without_improvement += 1

            if epochs_without_improvement >= 50:
                return results
    return results

# %% [markdown]
# # Baseline

# %%
# Define parameters
learning_rates = [.00001]
optimizer_class = optim.Adam
activation_function = nn.Tanh()
loss_function = nn.CrossEntropyLoss()
n_chans1 = 32
hid_layer = 3

for lr in learning_rates:
    torch.manual_seed(123)

    model = FCNN_Base(n_chans1, 
                 hid_layer, 
                 activation_function
                 ).to(device, non_blocking=True)
    
    numel_list = [p.numel() for p in model.parameters ()]
    print(sum(numel_list), numel_list)
    
    optimizer = optimizer_class(model.parameters(), lr=lr)

    results = training_loop(
        n_epochs = 500,
        early_stop = True,
        train_updates = True,
        optimizer = optimizer,
        model = model,
        loss_fn = loss_function,
        train_loader = train_loader,
        val_loader = val_loader)
    
    # Get confusion matrix
    with torch.no_grad():
        val_y_pred = model(X_val)
    # Predicted class is the higher probability
    predicted_classes = torch.max(val_y_pred, 1)[1]
    y_val_np = y_val.cpu().numpy()
    cnf_matrix = confusion_matrix(y_val_np, predicted_classes.cpu().numpy())

    # Print results
    print("\nLearning Rate =", lr)
    print("Confusion matrix:\n", cnf_matrix)

    print(f"Training Results - Accuracy: {results['train']['accuracy']:.4f}, "
        f"Precision: {results['train']['precision']:.4f}, "
        f"Recall: {results['train']['recall']:.4f}, "
        f"F1 Score: {results['train']['f1_score']:.4f}")

    print(f"Validation Results - Accuracy: {results['val']['accuracy']:.4f}, "
        f"Precision: {results['val']['precision']:.4f}, "
        f"Recall: {results['val']['recall']:.4f}, "
        f"F1 Score: {results['val']['f1_score']:.4f}")

    # Confusion matrix using heatmap
    class_names = ['Down', 'Up']
    fig, ax = plt.subplots()
    # Create heatmap
    sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
    ax.xaxis.set_label_position("top")
    plt.tight_layout()
    plt.title('Confusion matrix', y=1.1)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    # Replace the x-axis and y-axis labels
    ax.set_xticklabels(class_names)
    ax.set_yticklabels(class_names)
# Out:
# 5490 [2272, 32, 2048, 64, 1024, 16, 32, 2]
# Epoch: 5, Training Loss: 0.698796, Training Accuracy: 0.4793, Validation Accuracy: 0.4259
# Epoch: 10, Training Loss: 0.697245, Training Accuracy: 0.4977, Validation Accuracy: 0.4074
# Epoch: 15, Training Loss: 0.695241, Training Accuracy: 0.5115, Validation Accuracy: 0.4259
# Epoch: 20, Training Loss: 0.693237, Training Accuracy: 0.5346, Validation Accuracy: 0.4630
# Epoch: 25, Training Loss: 0.691705, Training Accuracy: 0.5392, Validation Accuracy: 0.4444
# Epoch: 30, Training Loss: 0.689974, Training Accuracy: 0.5484, Validation Accuracy: 0.4815
# Epoch: 35, Training Loss: 0.688638, Training Accuracy: 0.5760, Validation Accuracy: 0.5000
# Epoch: 40, Training Loss: 0.686801, Training Accuracy: 0.5945, Validation Accuracy: 0.5185
# Epoch: 45, Training Loss: 0.684719, Training Accuracy: 0.6083, Validation Accuracy: 0.5556
# Epoch: 50, Training Loss: 0.683439, Training Accuracy: 0.6221, Validation Accuracy: 0.5741
# Epoch: 55, Training Loss: 0.681904, Training Accuracy: 0.6267, Validation Accuracy: 0.5741
# Epoch: 60, Training Loss: 0.680494, Training Accuracy: 0.6406, Validation Accuracy: 0.5741
# Epoch: 65, Training Loss: 0.678087, Training Accuracy: 0.6406, Validation Accuracy: 0.5741
# Epoch: 70, Training Loss: 0.676866, Training Accuracy: 0.6498, Validation Accuracy: 0.5741
# Epoch: 75, Training Loss: 0.675536, Training Accuracy: 0.6221, Validation Accuracy: 0.5741
# Epoch: 80, Training Loss: 0.673729, Training Accuracy: 0.6175, Validation Accuracy: 0.5741
# Epoch: 85, Training Loss: 0.672737, Training Accuracy: 0.6313, Validation Accuracy: 0.5926
# Epoch: 90, Training Loss: 0.670888, Training Accuracy: 0.6406, Validation Accuracy: 0.5741
# Epoch: 95, Training Loss: 0.669605, Training Accuracy: 0.6452, Validation Accuracy: 0.5741
# Epoch: 100, Training Loss: 0.669153, Training Accuracy: 0.6498, Validation Accuracy: 0.5556
# Epoch: 105, Training Loss: 0.667217, Training Accuracy: 0.6498, Validation Accuracy: 0.5556
# Epoch: 110, Training Loss: 0.666204, Training Accuracy: 0.6544, Validation Accuracy: 0.5556
# Epoch: 115, Training Loss: 0.664316, Training Accuracy: 0.6544, Validation Accuracy: 0.5556
# Epoch: 120, Training Loss: 0.662233, Training Accuracy: 0.6452, Validation Accuracy: 0.5556
# Epoch: 125, Training Loss: 0.660682, Training Accuracy: 0.6498, Validation Accuracy: 0.5741
# Epoch: 130, Training Loss: 0.659468, Training Accuracy: 0.6544, Validation Accuracy: 0.5926
#
# Learning Rate = 1e-05
# Confusion matrix:
#  [[ 0 19]
#  [ 3 32]]
# Training Results - Accuracy: 0.6544, Precision: 0.6685, Recall: 0.8897, F1 Score: 0.7634
# Validation Results - Accuracy: 0.5926, Precision: 0.6275, Recall: 0.9143, F1 Score: 0.7442

# %% [markdown]
# # Hyperparameter search

# %%
# Define parameter space
learning_rate_options = [1, 0.1, 0.01, 0.001, 0.0001, 0.00001]
optimizer_options = [optim.SGD, optim.Adam]
activation_options = [nn.Sigmoid(), nn.ReLU(), nn.Tanh(), nn.LeakyReLU()]
n_chans1_options = [16, 32, 64, 128]
hid_layers_options = [1, 2, 3]
dropout_prob_options = [0.5, 0.6]

resultsList = []

# Exhaustive grid search
for lr in learning_rate_options:
    for optimizer_class in optimizer_options:
        for activation_function in activation_options:
            for n_chans1 in n_chans1_options:
                for hid_layers in hid_layers_options:
                    for dropout_prob in dropout_prob_options:
                        torch.manual_seed(123)

                        model = FCNN(n_chans1, 
                                     hid_layers, 
                                     activation_function, 
                                     dropout_prob
                                     ).to(device, non_blocking=True)
                        
                        optimizer = optimizer_class(model.parameters(), lr=lr)
                        loss_function = nn.CrossEntropyLoss()

                        results = training_loop(
                            n_epochs = 500,
                            early_stop = True,
                            train_updates = False,
                            optimizer = optimizer,
                            model = model,
                            loss_fn = loss_function,
                            train_loader = train_loader,
                            val_loader = val_loader)

                        # Add the results
                        val_results = results['val']
                        val_results['lr'] = lr
                        val_results['optimizer'] = optimizer_class.__name__
                        val_results['activation_function'] = type(activation_function).__name__
                        val_results['loss_function'] = type(loss_function).__name__
                        val_results['n_chans1'] = n_chans1
                        val_results['hid_layer'] = hid_layers
                        val_results['dropout_prob'] = dropout_prob
                        resultsList.append(val_results)

# Sort results by single metric
resultsList = sorted(resultsList, key=lambda x: x['precision'], reverse=True) 
for result in resultsList: 
    print(result)
# Out:
# {'accuracy': 0.37037037037037035, 'f1_score': 0.05555555555555556, 'precision': 1.0, 'recall': 0.02857142857142857, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.2857142857142857, 'precision': 0.8571428571428571, 'recall': 0.17142857142857143, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.7037037037037037, 'f1_score': 0.7647058823529412, 'precision': 0.7878787878787878, 'recall': 0.7428571428571429, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5, 'f1_score': 0.44897959183673464, 'precision': 0.7857142857142857, 'recall': 0.3142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6851851851851852, 'f1_score': 0.7462686567164178, 'precision': 0.78125, 'recall': 0.7142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6851851851851852, 'f1_score': 0.7462686567164178, 'precision': 0.78125, 'recall': 0.7142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.3181818181818182, 'precision': 0.7777777777777778, 'recall': 0.2, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7272727272727272, 'precision': 0.7741935483870968, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7272727272727272, 'precision': 0.7741935483870968, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7272727272727272, 'precision': 0.7741935483870968, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5, 'precision': 0.7647058823529411, 'recall': 0.37142857142857144, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5, 'precision': 0.7647058823529411, 'recall': 0.37142857142857144, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6333333333333332, 'precision': 0.76, 'recall': 0.5428571428571428, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6333333333333332, 'precision': 0.76, 'recall': 0.5428571428571428, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.46296296296296297, 'f1_score': 0.3829787234042553, 'precision': 0.75, 'recall': 0.2571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.46296296296296297, 'f1_score': 0.3829787234042553, 'precision': 0.75, 'recall': 0.2571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.46296296296296297, 'f1_score': 0.3829787234042553, 'precision': 0.75, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.46296296296296297, 'f1_score': 0.3829787234042553, 'precision': 0.75, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.46296296296296297, 'f1_score': 0.3829787234042553, 'precision': 0.75, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.46296296296296297, 'f1_score': 0.3829787234042553, 'precision': 0.75, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.46296296296296297, 'f1_score': 0.3829787234042553, 'precision': 0.75, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.75, 'precision': 0.7297297297297297, 'recall': 0.7714285714285715, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.34782608695652173, 'precision': 0.7272727272727273, 'recall': 0.22857142857142856, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.5614035087719298, 'precision': 0.7272727272727273, 'recall': 0.45714285714285713, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.7407407407407407, 'f1_score': 0.8292682926829269, 'precision': 0.723404255319149, 'recall': 0.9714285714285714, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5, 'f1_score': 0.490566037735849, 'precision': 0.7222222222222222, 'recall': 0.37142857142857144, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5, 'f1_score': 0.490566037735849, 'precision': 0.7222222222222222, 'recall': 0.37142857142857144, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5, 'f1_score': 0.490566037735849, 'precision': 0.7222222222222222, 'recall': 0.37142857142857144, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5, 'f1_score': 0.490566037735849, 'precision': 0.7222222222222222, 'recall': 0.37142857142857144, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7567567567567569, 'precision': 0.717948717948718, 'recall': 0.8, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7142857142857143, 'precision': 0.7142857142857143, 'recall': 0.7142857142857143, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5357142857142858, 'precision': 0.7142857142857143, 'recall': 0.42857142857142855, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5357142857142858, 'precision': 0.7142857142857143, 'recall': 0.42857142857142855, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6666666666666666, 'precision': 0.7096774193548387, 'recall': 0.6285714285714286, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6666666666666666, 'precision': 0.7096774193548387, 'recall': 0.6285714285714286, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6666666666666666, 'precision': 0.7096774193548387, 'recall': 0.6285714285714286, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6666666666666666, 'precision': 0.7096774193548387, 'recall': 0.6285714285714286, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.576271186440678, 'precision': 0.7083333333333334, 'recall': 0.4857142857142857, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7631578947368421, 'precision': 0.7073170731707317, 'recall': 0.8285714285714286, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7631578947368421, 'precision': 0.7073170731707317, 'recall': 0.8285714285714286, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7631578947368421, 'precision': 0.7073170731707317, 'recall': 0.8285714285714286, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7631578947368421, 'precision': 0.7073170731707317, 'recall': 0.8285714285714286, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.6956521739130436, 'precision': 0.7058823529411765, 'recall': 0.6857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.6956521739130436, 'precision': 0.7058823529411765, 'recall': 0.6857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.6956521739130436, 'precision': 0.7058823529411765, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.6956521739130436, 'precision': 0.7058823529411765, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.6956521739130436, 'precision': 0.7058823529411765, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.6956521739130436, 'precision': 0.7058823529411765, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.6129032258064516, 'precision': 0.7037037037037037, 'recall': 0.5428571428571428, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7222222222222223, 'precision': 0.7027027027027027, 'recall': 0.7428571428571429, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7222222222222223, 'precision': 0.7027027027027027, 'recall': 0.7428571428571429, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7222222222222223, 'precision': 0.7027027027027027, 'recall': 0.7428571428571429, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6461538461538462, 'precision': 0.7, 'recall': 0.6, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5, 'f1_score': 0.509090909090909, 'precision': 0.7, 'recall': 0.4, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7466666666666666, 'precision': 0.7, 'recall': 0.8, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6461538461538462, 'precision': 0.7, 'recall': 0.6, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6461538461538462, 'precision': 0.7, 'recall': 0.6, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6461538461538462, 'precision': 0.7, 'recall': 0.6, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.676470588235294, 'precision': 0.696969696969697, 'recall': 0.6571428571428571, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.676470588235294, 'precision': 0.696969696969697, 'recall': 0.6571428571428571, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.676470588235294, 'precision': 0.696969696969697, 'recall': 0.6571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6851851851851852, 'f1_score': 0.7901234567901234, 'precision': 0.6956521739130435, 'recall': 0.9142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5517241379310345, 'precision': 0.6956521739130435, 'recall': 0.45714285714285713, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5517241379310345, 'precision': 0.6956521739130435, 'recall': 0.45714285714285713, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5517241379310345, 'precision': 0.6956521739130435, 'recall': 0.45714285714285713, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6851851851851852, 'f1_score': 0.7901234567901234, 'precision': 0.6956521739130435, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5517241379310345, 'precision': 0.6956521739130435, 'recall': 0.45714285714285713, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7042253521126761, 'precision': 0.6944444444444444, 'recall': 0.7142857142857143, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7042253521126761, 'precision': 0.6944444444444444, 'recall': 0.7142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7042253521126761, 'precision': 0.6944444444444444, 'recall': 0.7142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7297297297297296, 'precision': 0.6923076923076923, 'recall': 0.7714285714285715, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7297297297297296, 'precision': 0.6923076923076923, 'recall': 0.7714285714285715, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7297297297297296, 'precision': 0.6923076923076923, 'recall': 0.7714285714285715, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7297297297297296, 'precision': 0.6923076923076923, 'recall': 0.7714285714285715, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.7297297297297296, 'precision': 0.6923076923076923, 'recall': 0.7714285714285715, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.37499999999999994, 'precision': 0.6923076923076923, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.37499999999999994, 'precision': 0.6923076923076923, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7532467532467533, 'precision': 0.6904761904761905, 'recall': 0.8285714285714286, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.625, 'precision': 0.6896551724137931, 'recall': 0.5714285714285714, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.625, 'precision': 0.6896551724137931, 'recall': 0.5714285714285714, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.625, 'precision': 0.6896551724137931, 'recall': 0.5714285714285714, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.625, 'precision': 0.6896551724137931, 'recall': 0.5714285714285714, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.775, 'precision': 0.6888888888888889, 'recall': 0.8857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6567164179104478, 'precision': 0.6875, 'recall': 0.6285714285714286, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6567164179104478, 'precision': 0.6875, 'recall': 0.6285714285714286, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6567164179104478, 'precision': 0.6875, 'recall': 0.6285714285714286, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6567164179104478, 'precision': 0.6875, 'recall': 0.6285714285714286, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6567164179104478, 'precision': 0.6875, 'recall': 0.6285714285714286, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6857142857142857, 'precision': 0.6857142857142857, 'recall': 0.6857142857142857, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6857142857142857, 'precision': 0.6857142857142857, 'recall': 0.6857142857142857, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6857142857142857, 'precision': 0.6857142857142857, 'recall': 0.6857142857142857, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6857142857142857, 'precision': 0.6857142857142857, 'recall': 0.6857142857142857, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6857142857142857, 'precision': 0.6857142857142857, 'recall': 0.6857142857142857, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6857142857142857, 'precision': 0.6857142857142857, 'recall': 0.6857142857142857, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6857142857142857, 'precision': 0.6857142857142857, 'recall': 0.6857142857142857, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6857142857142857, 'precision': 0.6857142857142857, 'recall': 0.6857142857142857, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7123287671232877, 'precision': 0.6842105263157895, 'recall': 0.7428571428571429, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7123287671232877, 'precision': 0.6842105263157895, 'recall': 0.7428571428571429, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7123287671232877, 'precision': 0.6842105263157895, 'recall': 0.7428571428571429, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7123287671232877, 'precision': 0.6842105263157895, 'recall': 0.7428571428571429, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7123287671232877, 'precision': 0.6842105263157895, 'recall': 0.7428571428571429, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7123287671232877, 'precision': 0.6842105263157895, 'recall': 0.7428571428571429, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.7123287671232877, 'precision': 0.6842105263157895, 'recall': 0.7428571428571429, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.48148148148148145, 'f1_score': 0.4814814814814815, 'precision': 0.6842105263157895, 'recall': 0.37142857142857144, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.736842105263158, 'precision': 0.6829268292682927, 'recall': 0.8, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.736842105263158, 'precision': 0.6829268292682927, 'recall': 0.8, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6296296296296297, 'f1_score': 0.736842105263158, 'precision': 0.6829268292682927, 'recall': 0.8, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5, 'f1_score': 0.5263157894736843, 'precision': 0.6818181818181818, 'recall': 0.42857142857142855, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5, 'f1_score': 0.5263157894736843, 'precision': 0.6818181818181818, 'recall': 0.42857142857142855, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5666666666666667, 'precision': 0.68, 'recall': 0.4857142857142857, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5185185185185185, 'f1_score': 0.5666666666666667, 'precision': 0.68, 'recall': 0.4857142857142857, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.603174603174603, 'precision': 0.6785714285714286, 'recall': 0.5428571428571428, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.603174603174603, 'precision': 0.6785714285714286, 'recall': 0.5428571428571428, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.603174603174603, 'precision': 0.6785714285714286, 'recall': 0.5428571428571428, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.603174603174603, 'precision': 0.6785714285714286, 'recall': 0.5428571428571428, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.603174603174603, 'precision': 0.6785714285714286, 'recall': 0.5428571428571428, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.603174603174603, 'precision': 0.6785714285714286, 'recall': 0.5428571428571428, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5370370370370371, 'f1_score': 0.603174603174603, 'precision': 0.6785714285714286, 'recall': 0.5428571428571428, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.6363636363636364, 'precision': 0.6774193548387096, 'recall': 0.6, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.6363636363636364, 'precision': 0.6774193548387096, 'recall': 0.6, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.6363636363636364, 'precision': 0.6774193548387096, 'recall': 0.6, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.6363636363636364, 'precision': 0.6774193548387096, 'recall': 0.6, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.6363636363636364, 'precision': 0.6774193548387096, 'recall': 0.6, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.6363636363636364, 'precision': 0.6774193548387096, 'recall': 0.6, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5555555555555556, 'f1_score': 0.6363636363636364, 'precision': 0.6774193548387096, 'recall': 0.6, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5740740740740741, 'f1_score': 0.6666666666666666, 'precision': 0.6764705882352942, 'recall': 0.6571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.5925925925925926, 'f1_score': 0.6944444444444444, 'precision': 0.6756756756756757, 'recall': 0.7142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 0.001, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6111111111111112, 'f1_score': 0.72, 'precision': 0.675, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# ...
# {'accuracy': 0.4444444444444444, 'f1_score': 0.5833333333333333, 'precision': 0.5675675675675675, 'recall': 0.6, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.5833333333333333, 'precision': 0.5675675675675675, 'recall': 0.6, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.523076923076923, 'precision': 0.5666666666666667, 'recall': 0.4857142857142857, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.5945945945945945, 'precision': 0.5641025641025641, 'recall': 0.6285714285714286, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.5373134328358209, 'precision': 0.5625, 'recall': 0.5142857142857142, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.5373134328358209, 'precision': 0.5625, 'recall': 0.5142857142857142, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.605263157894737, 'precision': 0.5609756097560976, 'recall': 0.6571428571428571, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.4444444444444444, 'f1_score': 0.605263157894737, 'precision': 0.5609756097560976, 'recall': 0.6571428571428571, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.5753424657534247, 'precision': 0.5526315789473685, 'recall': 0.6, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.4, 'precision': 0.55, 'recall': 0.3142857142857143, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.4, 'precision': 0.55, 'recall': 0.3142857142857143, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.5866666666666667, 'precision': 0.55, 'recall': 0.6285714285714286, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.42105263157894735, 'precision': 0.5454545454545454, 'recall': 0.34285714285714286, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.5428571428571428, 'precision': 0.5428571428571428, 'recall': 0.5428571428571428, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.44067796610169496, 'precision': 0.5416666666666666, 'recall': 0.37142857142857144, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.44067796610169496, 'precision': 0.5416666666666666, 'recall': 0.37142857142857144, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.4923076923076923, 'precision': 0.5333333333333333, 'recall': 0.45714285714285713, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.34615384615384615, 'precision': 0.5294117647058824, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.34615384615384615, 'precision': 0.5294117647058824, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.34615384615384615, 'precision': 0.5294117647058824, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.34615384615384615, 'precision': 0.5294117647058824, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.37037037037037035, 'precision': 0.5263157894736842, 'recall': 0.2857142857142857, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.37037037037037035, 'precision': 0.5263157894736842, 'recall': 0.2857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.46875000000000006, 'precision': 0.5172413793103449, 'recall': 0.42857142857142855, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3333333333333333, 'f1_score': 0.09999999999999999, 'precision': 0.4, 'recall': 0.05714285714285714, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.3148148148148148, 'f1_score': 0.17777777777777776, 'precision': 0.4, 'recall': 0.11428571428571428, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3148148148148148, 'f1_score': 0.17777777777777776, 'precision': 0.4, 'recall': 0.11428571428571428, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3333333333333333, 'f1_score': 0.05263157894736842, 'precision': 0.3333333333333333, 'recall': 0.02857142857142857, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.2962962962962963, 'f1_score': 0.13636363636363638, 'precision': 0.3333333333333333, 'recall': 0.08571428571428572, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.2962962962962963, 'f1_score': 0.13636363636363638, 'precision': 0.3333333333333333, 'recall': 0.08571428571428572, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}

# %%
# Sort results by single metric
resultsList = sorted(resultsList, key=lambda x: x['accuracy'], reverse=True) 
for result in resultsList: 
    print(result)
# Out:
# {'accuracy': 0.7407407407407407, 'f1_score': 0.8292682926829269, 'precision': 0.723404255319149, 'recall': 0.9714285714285714, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.7037037037037037, 'f1_score': 0.7647058823529412, 'precision': 0.7878787878787878, 'recall': 0.7428571428571429, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6851851851851852, 'f1_score': 0.7462686567164178, 'precision': 0.78125, 'recall': 0.7142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6851851851851852, 'f1_score': 0.7462686567164178, 'precision': 0.78125, 'recall': 0.7142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6851851851851852, 'f1_score': 0.7901234567901234, 'precision': 0.6956521739130435, 'recall': 0.9142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6851851851851852, 'f1_score': 0.7901234567901234, 'precision': 0.6956521739130435, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7272727272727272, 'precision': 0.7741935483870968, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7272727272727272, 'precision': 0.7741935483870968, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7272727272727272, 'precision': 0.7741935483870968, 'recall': 0.6857142857142857, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.75, 'precision': 0.7297297297297297, 'recall': 0.7714285714285715, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7567567567567569, 'precision': 0.717948717948718, 'recall': 0.8, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7631578947368421, 'precision': 0.7073170731707317, 'recall': 0.8285714285714286, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7631578947368421, 'precision': 0.7073170731707317, 'recall': 0.8285714285714286, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7631578947368421, 'precision': 0.7073170731707317, 'recall': 0.8285714285714286, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7631578947368421, 'precision': 0.7073170731707317, 'recall': 0.8285714285714286, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.775, 'precision': 0.6888888888888889, 'recall': 0.8857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7804878048780487, 'precision': 0.6808510638297872, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7954545454545454, 'precision': 0.660377358490566, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7954545454545454, 'precision': 0.660377358490566, 'recall': 1.0, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7954545454545454, 'precision': 0.660377358490566, 'recall': 1.0, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6666666666666666, 'f1_score': 0.7954545454545454, 'precision': 0.660377358490566, 'recall': 1.0, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7397260273972601, 'precision': 0.7105263157894737, 'recall': 0.7714285714285715, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7466666666666666, 'precision': 0.7, 'recall': 0.8, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7532467532467533, 'precision': 0.6904761904761905, 'recall': 0.8285714285714286, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.759493670886076, 'precision': 0.6818181818181818, 'recall': 0.8571428571428571, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7654320987654321, 'precision': 0.6739130434782609, 'recall': 0.8857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7654320987654321, 'precision': 0.6739130434782609, 'recall': 0.8857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7654320987654321, 'precision': 0.6739130434782609, 'recall': 0.8857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7710843373493975, 'precision': 0.6666666666666666, 'recall': 0.9142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7710843373493975, 'precision': 0.6666666666666666, 'recall': 0.9142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7710843373493975, 'precision': 0.6666666666666666, 'recall': 0.9142857142857143, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7710843373493975, 'precision': 0.6666666666666666, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7710843373493975, 'precision': 0.6666666666666666, 'recall': 0.9142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7764705882352942, 'precision': 0.66, 'recall': 0.9428571428571428, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7764705882352942, 'precision': 0.66, 'recall': 0.9428571428571428, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7764705882352942, 'precision': 0.66, 'recall': 0.9428571428571428, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7764705882352942, 'precision': 0.66, 'recall': 0.9428571428571428, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7764705882352942, 'precision': 0.66, 'recall': 0.9428571428571428, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7816091954022988, 'precision': 0.6538461538461539, 'recall': 0.9714285714285714, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7816091954022988, 'precision': 0.6538461538461539, 'recall': 0.9714285714285714, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7816091954022988, 'precision': 0.6538461538461539, 'recall': 0.9714285714285714, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7816091954022988, 'precision': 0.6538461538461539, 'recall': 0.9714285714285714, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7816091954022988, 'precision': 0.6538461538461539, 'recall': 0.9714285714285714, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.6481481481481481, 'f1_score': 0.7865168539325843, 'precision': 0.6481481481481481, 'recall': 1.0, 'lr': 0.01, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# ...
# {'accuracy': 0.42592592592592593, 'f1_score': 0.523076923076923, 'precision': 0.5666666666666667, 'recall': 0.4857142857142857, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.5373134328358209, 'precision': 0.5625, 'recall': 0.5142857142857142, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.5373134328358209, 'precision': 0.5625, 'recall': 0.5142857142857142, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.5753424657534247, 'precision': 0.5526315789473685, 'recall': 0.6, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.42592592592592593, 'f1_score': 0.5866666666666667, 'precision': 0.55, 'recall': 0.6285714285714286, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.36, 'precision': 0.6, 'recall': 0.2571428571428571, 'lr': 0.1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.40740740740740744, 'precision': 0.5789473684210527, 'recall': 0.3142857142857143, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.4666666666666667, 'precision': 0.56, 'recall': 0.4, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.4074074074074074, 'f1_score': 0.5428571428571428, 'precision': 0.5428571428571428, 'recall': 0.5428571428571428, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.19512195121951217, 'precision': 0.6666666666666666, 'recall': 0.11428571428571428, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.32653061224489793, 'precision': 0.5714285714285714, 'recall': 0.22857142857142856, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.3773584905660377, 'precision': 0.5555555555555556, 'recall': 0.2857142857142857, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.4, 'precision': 0.55, 'recall': 0.3142857142857143, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.4, 'precision': 0.55, 'recall': 0.3142857142857143, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.42105263157894735, 'precision': 0.5454545454545454, 'recall': 0.34285714285714286, 'lr': 0.0001, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.44067796610169496, 'precision': 0.5416666666666666, 'recall': 0.37142857142857144, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.44067796610169496, 'precision': 0.5416666666666666, 'recall': 0.37142857142857144, 'lr': 0.01, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3888888888888889, 'f1_score': 0.4923076923076923, 'precision': 0.5333333333333333, 'recall': 0.45714285714285713, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.05555555555555556, 'precision': 1.0, 'recall': 0.02857142857142857, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.34615384615384615, 'precision': 0.5294117647058824, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.34615384615384615, 'precision': 0.5294117647058824, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.34615384615384615, 'precision': 0.5294117647058824, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.5}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.34615384615384615, 'precision': 0.5294117647058824, 'recall': 0.2571428571428571, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.37037037037037035, 'precision': 0.5263157894736842, 'recall': 0.2857142857142857, 'lr': 1, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.37037037037037035, 'precision': 0.5263157894736842, 'recall': 0.2857142857142857, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.37037037037037035, 'f1_score': 0.46875000000000006, 'precision': 0.5172413793103449, 'recall': 0.42857142857142855, 'lr': 0.001, 'optimizer': 'SGD', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Tanh', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 0.0001, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 16, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.35185185185185186, 'f1_score': 0.0, 'precision': 0.0, 'recall': 0.0, 'lr': 1e-05, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 64, 'hid_layer': 3, 'dropout_prob': 0.6}
# {'accuracy': 0.3333333333333333, 'f1_score': 0.09999999999999999, 'precision': 0.4, 'recall': 0.05714285714285714, 'lr': 1, 'optimizer': 'Adam', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 32, 'hid_layer': 1, 'dropout_prob': 0.6}
# {'accuracy': 0.3333333333333333, 'f1_score': 0.05263157894736842, 'precision': 0.3333333333333333, 'recall': 0.02857142857142857, 'lr': 0.1, 'optimizer': 'SGD', 'activation_function': 'Sigmoid', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.3148148148148148, 'f1_score': 0.17777777777777776, 'precision': 0.4, 'recall': 0.11428571428571428, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.3148148148148148, 'f1_score': 0.17777777777777776, 'precision': 0.4, 'recall': 0.11428571428571428, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.5}
# {'accuracy': 0.2962962962962963, 'f1_score': 0.13636363636363638, 'precision': 0.3333333333333333, 'recall': 0.08571428571428572, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'ReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}
# {'accuracy': 0.2962962962962963, 'f1_score': 0.13636363636363638, 'precision': 0.3333333333333333, 'recall': 0.08571428571428572, 'lr': 1e-05, 'optimizer': 'SGD', 'activation_function': 'LeakyReLU', 'loss_function': 'CrossEntropyLoss', 'n_chans1': 128, 'hid_layer': 2, 'dropout_prob': 0.6}

# %% [markdown]
# # Results

# %%
# Define parameters
learning_rates = [.00001]
optimizer_class = optim.Adam
activation_function = nn.Tanh()
loss_function = nn.CrossEntropyLoss()
n_chans1 = 16
hid_layer = 2
dropout_prob = 0.6

for lr in learning_rates:
    torch.manual_seed(123)

    model = FCNN(n_chans1, 
                 hid_layer, 
                 activation_function, 
                 dropout_prob
                 ).to(device, non_blocking=True)
    
    numel_list = [p.numel() for p in model.parameters ()]
    print(sum(numel_list), numel_list)
    
    optimizer = optimizer_class(model.parameters(), lr=lr)

    results = training_loop(
        n_epochs = 500,
        early_stop = True,
        train_updates = False,
        optimizer = optimizer,
        model = model,
        loss_fn = loss_function,
        train_loader = train_loader,
        val_loader = val_loader)
    
    # Get confusion matrix
    with torch.no_grad():
        val_y_pred = model(X_val)
    # Predicted class is the higher probability
    predicted_classes = torch.max(val_y_pred, 1)[1]
    y_val_np = y_val.cpu().numpy()
    cnf_matrix = confusion_matrix(y_val_np, predicted_classes.cpu().numpy())

    # Print results
    print("\nLearning Rate =", lr)
    print("Confusion matrix:\n", cnf_matrix)

    print(f"Training Results - Accuracy: {results['train']['accuracy']:.4f}, "
        f"Precision: {results['train']['precision']:.4f}, "
        f"Recall: {results['train']['recall']:.4f}, "
        f"F1 Score: {results['train']['f1_score']:.4f}")

    print(f"Validation Results - Accuracy: {results['val']['accuracy']:.4f}, "
        f"Precision: {results['val']['precision']:.4f}, "
        f"Recall: {results['val']['recall']:.4f}, "
        f"F1 Score: {results['val']['f1_score']:.4f}")

    # Confusion matrix using heatmap
    class_names = ['Down', 'Up']
    fig, ax = plt.subplots()
    # Create heatmap
    sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu", fmt='g')
    ax.xaxis.set_label_position("top")
    plt.tight_layout()
    plt.title('Confusion matrix', y=1.1)
    plt.ylabel('Actual label')
    plt.xlabel('Predicted label')

    # Replace the x-axis and y-axis labels
    ax.set_xticklabels(class_names)
    ax.set_yticklabels(class_names)
# Out:
# 1858 [1136, 16, 16, 16, 512, 32, 32, 32, 64, 2]
#
# Learning Rate = 1e-05
# Confusion matrix:
#  [[12  7]
#  [ 9 26]]
# Training Results - Accuracy: 0.4747, Precision: 0.5859, Recall: 0.5515, F1 Score: 0.5682
# Validation Results - Accuracy: 0.7037, Precision: 0.7879, Recall: 0.7429, F1 Score: 0.7647
